# %%
import pandas as pd
import os

# %% [markdown]
# ### Merging 12 months of sales into a single file

# %%
pwd #con esta linea de codigo averiguamos en que direcorio estamos trabajando
# Out:
# 'C:\\Users\\nico.-\\Untitled Folder\\Pandas'

# %%
df = pd.read_csv('./Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/Sales_April_2019.csv')

# %%
df.tail() #este archivo tiene 18 mil filas!!! Es en Excel es casi imposible de manejar!!
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
df.index #esta linea esta buena porque te permite ver cuantas filas tiene el archivo
# Out:
# RangeIndex(start=0, stop=18383, step=1)

# %%
df.iloc[4]
# Out:
# Order ID                                          176560
# Product                                 Wired Headphones
# Quantity Ordered                                       1
# Price Each                                         11.99
# Order Date                                04/12/19 14:38
# Purchase Address    669 Spruce St, Los Angeles, CA 90001
# Name: 4, dtype: object

# %%
df.loc[df['Product'] == 'Google Phone']
# Out:
#       Order ID       Product Quantity Ordered Price Each      Order Date  \
# 3       176560  Google Phone                1        600  04/12/19 14:38
# 11      176567  Google Phone                1        600  04/18/19 17:18
# 18      176574  Google Phone                1        600  04/03/19 19:42
# 33      176586  Google Phone                1        600  04/10/19 17:00
# 37      176590  Google Phone                1        600  04/11/19 11:46
# ...        ...           ...              ...        ...             ...
# 18276   193994  Google Phone                1        600  04/28/19 20:34
# 18305   194021  Google Phone                1        600  04/29/19 14:50
# 18327   194042  Google Phone                1        600  04/22/19 21:42
# 18374   194086  Google Phone                1        600  04/28/19 08:50
# 18378   194090  Google Phone                1        600  04/08/19 17:11
#
#                              Purchase Address
# ...

# %%
#files = [file for file in os.listdir('./Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/')]  #no entiendo para que
#sirve esta linea de codigo.

#all_months_data = pd.DataFrame()


#for file in files:
    df = pd.read_csv('./Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data,df])
    
#all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
#all_months_data.tail(20)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 11666   259339        USB-C Charging Cable                2      11.95
# 11667   259340       AA Batteries (4-pack)                2       3.84
# 11668   259341      27in 4K Gaming Monitor                1     389.99
# 11669   259342       AA Batteries (4-pack)                1       3.84
# 11670   259343        USB-C Charging Cable                1      11.95
# 11671   259344      AAA Batteries (4-pack)                2       2.99
# 11672   259345             ThinkPad Laptop                1     999.99
# 11673   259346  Bose SoundSport Headphones                1      99.99
# 11674   259347       AA Batteries (4-pack)                1       3.84
# 11675   259348    Lightning Charging Cable                1      14.95
# 11676   259349      AAA Batteries (4-pack)                1       2.99
# 11677   259350                Google Phone                1        600
# ...

# %%
#all_months_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# En este punto conseguimos tener un unico archivo que se llama 'all_data' y que tiene la informacions de ventas de 12 meses!!.

# %%
all_data = pd.read_csv('all_data.csv')
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Question 1===> What was the best moth for sales? How much was earned that motn?

# %% [markdown]
# En primer lugar vamos a incorporar una columna adicional que contenga los meses. Porque en la df tal como esta no esta muy accesible el mes

# %%
all_data.iloc[0,-2][:2]
# Out:
# '04'

# %% [markdown]
# ### Clean the Data.
# Vamos a eliminar las celdas que tienen NaN

# %%
all_data[all_data.isna().any(axis=1)] #con esta linea averiguamos que habia un monton de NAN
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
all_data = all_data.dropna(how='all') #con esta linea los eliminamos

# %%
all_data[all_data.isna().any(axis=1)] #con esta linea los volvimos a buscar y ahora no hay nada
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or'] #con esta linea eliminamos todas las filas que contienen "or"
#que viene de "order date" en la columna "Order Date"
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data['Month'] = 3
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %% [markdown]
# ### Convert columns to the correct type

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ### add a sales column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data

#con estas lineas de codigo directamente creamos una columna que se llama 'Sales' que contien el prducto de las columnas 
#'Quantity Ordered' y 'Price Each'
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %% [markdown]
# ### tengo que eliminar la columna que se llama "$$ total"

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %%
results = all_data.groupby('Month').sum()
results
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %% [markdown]
# ### ahora podriamos hacer dos analisis: primero ver que mes vendimos mas productos y segundo que mes generamos mas ingresos. Si un mes se vendieran productos mas caros que otro mes, podria ser que hubiera algunas diferencias

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Sales')
months = range(1,13)
plt.bar(months, results['Sales'], edgecolor= 'black' )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.title('Quantity Ordered')
months = range(1,13)
plt.bar(months, results['Quantity Ordered'], edgecolor= 'black' )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
december_df = pd.read_csv('./Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/Sales_December_2019.csv')
december_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop                1       1700
# 1       295666          LG Washing Machine                1      600.0
# 2       295667        USB-C Charging Cable                1      11.95
# 3       295668            27in FHD Monitor                1     149.99
# 4       295669        USB-C Charging Cable                1      11.95
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
december_df['Day'] = december_df['Order Date'].str[3:5]
december_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop                1       1700
# 1       295666          LG Washing Machine                1      600.0
# 2       295667        USB-C Charging Cable                1      11.95
# 3       295668            27in FHD Monitor                1     149.99
# 4       295669        USB-C Charging Cable                1      11.95
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address Day
# ...

# %%
print(december_df.iloc[254])
# Out:
# Order ID                    Order ID
# Product                      Product
# Quantity Ordered    Quantity Ordered
# Price Each                Price Each
# Order Date                Order Date
# Purchase Address    Purchase Address
# Day                               er
# Name: 254, dtype: object

# %%
december_df = december_df[december_df['Order Date'] != 'Order Date']
december_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop                1       1700
# 1       295666          LG Washing Machine                1      600.0
# 2       295667        USB-C Charging Cable                1      11.95
# 3       295668            27in FHD Monitor                1     149.99
# 4       295669        USB-C Charging Cable                1      11.95
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address Day
# ...

# %%
december_df['Quantity Ordered'] = pd.to_numeric(december_df['Quantity Ordered'])
december_df
# Out:
# <ipython-input-21-1086f93760e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   december_df['Quantity Ordered'] = pd.to_numeric(december_df['Quantity Ordered'])
#       Order ID                     Product  Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop               1.0       1700
# 1       295666          LG Washing Machine               1.0      600.0
# 2       295667        USB-C Charging Cable               1.0      11.95
# 3       295668            27in FHD Monitor               1.0     149.99
# 4       295669        USB-C Charging Cable               1.0      11.95
# ...        ...                         ...               ...        ...
# ...

# %%
sales_per_day = december_df.groupby('Day').sum()
sales_per_day.head()

#all_data.groupby('Month').sum()
# Out:
#      Quantity Ordered
# Day
# 01              884.0
# 02              914.0
# 03              832.0
# 04              879.0
# 05              905.0

# %%
plt.title('December')
days = range(1,32)
plt.bar(days, sales_per_day['Quantity Ordered'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sales_per_day
# Out:
#      Quantity Ordered
# Day
# 01              884.0
# 02              914.0
# 03              832.0
# 04              879.0
# 05              905.0
# 06              910.0
# 07              843.0
# 08              870.0
# 09              856.0
# 10              897.0
# 11              894.0
# 12              919.0
# 13              957.0
# 14              924.0
# 15              915.0
# 16              914.0
# 17             1044.0
# 18              870.0
# 19              942.0
# 20              912.0
# 21              875.0
# 22              874.0
# 23              988.0
# 24              908.0
# 25              902.0
# 26              925.0
# 27              869.0
# 28              931.0
# 29              954.0
# 30              928.0
# 31              886.0

# %% [markdown]
# ### What city has the higher amount of sales?

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %%
all_data.head(25)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
# 6    176562        USB-C Charging Cable                 1       11.95
# 7    176563  Bose SoundSport Headphones                 1       99.99
# 8    176564        USB-C Charging Cable                 1       11.95
# 9    176565          Macbook Pro Laptop                 1     1700.00
# 10   176566            Wired Headphones                 1       11.99
# 11   176567                Google Phone                 1      600.00
# 12   176568    Lightning Charging Cable                 1       14.95
# ...

# %%
all_data['City'] = all_data['Purchase Address'].apply(lambda x:x.split(',')[1])  #esta funcin 'lambda' nunca la habia visto
#y no tengo ni idea como funciona

all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
city = all_data.groupby(all_data['City']).sum()  #notar que al aplicar esta funcions solo suma las filas que tienen valores
#numericos

city
# Out:
#                 Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta                   16602  2.779908e+06  104794  2.795499e+06
#  Austin                    11153  1.809874e+06   69829  1.819582e+06
#  Boston                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles               33289  5.421435e+06  208325  5.452571e+06
#  New York City             27932  4.635371e+06  175741  4.664317e+06
#  Portland                  14053  2.307747e+06   87765  2.320491e+06
#  San Francisco             50239  8.211462e+06  315520  8.262204e+06
#  Seattle                   16553  2.733296e+06  104941  2.747755e+06

# %%
all_data['City 2'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1])

all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
all_data = all_data.drop(columns='City')
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
all_data = all_data.drop(columns='City 2')

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %%
all_data['City'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1]) 
all_data['State'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[2].split(' ')[1]) 

all_data['City'] = all_data['City'] + ' ' + '(' + all_data['State'] + ')'

all_data = all_data.drop(columns= 'State')
all_data


#lo hice de una manera completamente diferente a como lo hicieron en el video...
#pero fui capaz de hacerlo usando los recursos con los que cuento hasta ahora!!!
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
city = all_data.groupby(all_data['City']).sum()
city
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
plt.title('Sales per city')

cities = [city for city, df in all_data.groupby('City')]

plt.bar(cities, city['Sales'], edgecolor= 'black', color='lightcoral', linewidth=2.5)
plt.xticks (cities, rotation=45, size=8)
plt.ylabel('Sales')
plt.xlabel('City')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Question 3. what time should we display advertisment to maximize likehood of costumers's buying product?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City
# 0        Dallas (TX)
# 2        Boston (MA)
# 3   Los Angeles (CA)
# 4   Los Angeles (CA)
# ...

# %%
all_data['Sale hour'] = all_data['Order Date'].apply(lambda x: x.split(' ')[1])
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City Sale hour
# 0        Dallas (TX)     08:46
# 2        Boston (MA)     22:30
# ...

# %%
all_data = all_data.drop(columns='Sale hour')
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City
# 0        Dallas (TX)
# 2        Boston (MA)
# 3   Los Angeles (CA)
# ...

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute

all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour  Minute
# 0        Dallas (TX)     8      46
# ...

# %%
hours = [hour for hour, df in all_data.groupby('Hour')]
plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xticks(hours)
plt.ylabel('Sales')
plt.grid()
plt.show()

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# ### What products al most often sold together?

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186792   259303       AA Batteries (4-pack)                 1        3.84
# 186803   259314            Wired Headphones                 1       11.99
# 186804   259314      AAA Batteries (4-pack)                 2        2.99
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                       Purchase Address  Month  \
# ...

# %%
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df
# Out:
# <ipython-input-60-ac6c5f1767d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# ...

# %%
df = df[['Order ID', 'Grouped']].drop_duplicates()
df
# Out:
#        Order ID                                            Grouped
# 3        176560                      Google Phone,Wired Headphones
# 18       176574                  Google Phone,USB-C Charging Cable
# 30       176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32       176586                AAA Batteries (4-pack),Google Phone
# 119      176672      Lightning Charging Cable,USB-C Charging Cable
# ...         ...                                                ...
# 186781   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 186783   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 186791   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803   259314            Wired Headphones,AAA Batteries (4-pack)
# 186841   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations 
from collections import Counter

# %%
count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))
    
type(count.most_common(10))
# Out:
# list

# %%
for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### what product sold the most?

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
#.groupby()
#.count()


best_seller = all_data.groupby('Product')
best_seller = best_seller.sum()
best_seller
# Out:
#                             Quantity Ordered  Price Each   Month       Sales  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
# con etas lineas vamos a ordenar la df de menor a mayor
df_sorted_desc= best_seller.sort_values('Quantity Ordered',ascending=True)

df_sorted_desc
# Out:
#                             Quantity Ordered  Price Each   Month       Sales  \
# Product
# LG Dryer                                 646   387600.00    4383   387600.00
# LG Washing Machine                       666   399600.00    4523   399600.00
# Vareebadd Phone                         2068   826000.00   14309   827200.00
# 20in Monitor                            4129   451068.99   29336   454148.71
# ThinkPad Laptop                         4130  4127958.72   28950  4129958.70
# Macbook Pro Laptop                      4728  8030800.00   33548  8037600.00
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# iPhone                                  6849  4789400.00   47941  4794300.00
# ...

# %%
plt.title('Best_seller')
plt.figure(figsize=(10,5))

#quantity_ordered = df_sorted_desc['Quantity Ordered']

#products = [product for product, df in best_seller]

plt.bar(products, quantity_ordered, data=df_sorted_desc)

plt.xticks (products, rotation='vertical', size=8)
plt.ylabel('Quantity Ordered')
plt.xlabel('Products')
# Out:
# Text(0.5, 0, 'Products')
